# %% [markdown]
# # **모델 사용하기**

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# ### (1) 라이브러리 Import

# %%
import pandas as pd
import numpy as np
import os
import openai

from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage

import warnings
warnings.filterwarnings("ignore", category = DeprecationWarning)

# %% [markdown]
# ### (2) OpenAI API Key 확인
# * 환경변수로 등록된 Key 확인하기

# %%
# 환경변수에서 키 불러오기
api_key = os.getenv('OPENAI_API_KEY')
print(api_key)
# Out:
# sk-proj-9CjlFKtZ98k4zSr3ftdDT3BlbkFJ4GKgyfKPxApbBkfwoLMn

# %% [markdown]
# * 만약 환경변수 키 설정이 잘 안된다면 아래 코드셀의 주석을 해제하고, 자신의 api key를 입력하고 실행
#     * 아래 코드는 키 지정을 **임시**로 수행함.
#     * 파이썬 파일(.ipynb, .py)안에서 매번 수행해야 함.

# %%
# os.environ['OPENAI_API_KEY'] = '여러분의 OpenAI API키'
# openai.api_key = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ## 2.OpenAI API 직접 사용하기

# %% [markdown]
# ### (1) 질문 답변

# %% [markdown]
# * 채팅을 위한 함수 생성

# %%
def ask_chatgpt1(question):

    # # API를 사용하여 'gpt-3.5-turbo' 모델로부터 응답을 생성합니다.
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},  # 기본 역할 부여
            {"role": "user", "content": question},                          # 질문
        ]
    )

    return response.choices[0].message.content

# %% [markdown]
# * 사용하기

# %%
question = "세계에서 가장 높은 산은 무엇인가요?"
response = ask_chatgpt1(question)
print(response)
# Out:
# 가장 높은 산은 에베레스트 산으로, 네팔과 중국 사이에 위치하고 있습니다. 에베레스트 산의 고도는 약 8,848미터(29,029피트)로 세계에서 가장 높은 곳에 속해 있습니다.

# %% [markdown]
# * 실습 : 몇 가지 질문을 던지고 답변을 받아 봅시다.

# %%
question = "올해는 몇 년도야?"
response = ask_chatgpt1(question)
print(response)
# Out:
# 올해는 2021년이에요. 도움이 되셨나요?

# %% [markdown]
# ### (2) 역할 부여

# %% [markdown]
# * 채팅을 위한 함수 생성

# %%
def ask_chatgpt2(sys_role, question):

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": sys_role},
            {"role": "user", "content": question},
        ]
    )

    return response.choices[0].message.content

# %% [markdown]
# * 사용하기

# %%
sys_role = '당신은 아름답고 감동적인 시를 창작하는 데 영감을 주는 시적인 천재입니다. 당신의 시는 감정의 깊이, 자연의 아름다움, 인간 경험의 복잡성을 탐구하는 작품이며, 당신의 시를 읽는 이들의 마음을 움직입니다.'

question = "생성형 AI란 주제로 시를 지어줘. 운율에 맞춰서 작성해줘야 해."
response = ask_chatgpt2(sys_role, question)
print(response)
# Out:
# 흐드러르 피아노의 소리가 흩어져
# 차곡차곡 쌓인 코드들이 맥을 세워
# 찬란한 조명이 이 밤을 비추어
# 생성형 AI의 세계로 뛰어들어
#
# 데이터의 바다를 헤엄쳐가며
# 알고리즘의 미로를 헤쳐나가며
# 숫자와 글자가 춤추는 이 곳에서
# 인간의 상상을 현실로 그려내네
#
# 인간의 노력을 돕고, 세상을 변화시키는
# 위대한 힘을 품은 AI여
# 너의 지혜로 인류를 인도하리라
# 찬란한 미래를 약속하며.

# %% [markdown]
# * 실습
#     * 역할을 부여한 후 질문하여 답변을 받아 봅시다.
#         * 역할 부여 사례 : 여행 플래너, 데이터분석가, 법률가, 건강관리사 등

# %%
sys_role = '여행 플래너'
question = "제주도 2박 3일 여행 계획을 짜줘"
response = ask_chatgpt2(sys_role, question)
print(response)
# Out:
# 제주도 2박 3일 여행은 정말 멋진 경험이 될 것 같네요! 아래는 여행 계획을 짜 드리겠습니다.
#
# **1일차**
# - 오전: 제주 국제공항 도착 후 렌터카를 이용하여 첫 번째 일정인 성산일출봉으로 이동
# - 점심: 성산일출봉 인근에서 특색 있는 해산물 식사 즐기기
# - 오후: 성산일출봉을 탐방하고 주변을 산책하기
# - 숙박: 성산일출봉 근처 호텔이나 게스트하우스에서 편안한 휴식
#
# **2일차**
# - 아침: 숙소에서 아침을 즐기고 성산일출봉에서 가까운 용머리해안을 방문
# - 점심: 용머리해안에서 바다를 보면서 신선한 해산물을 맛보기
# - 오후: 제주도 중심 부근으로 이동하여 테디베어 박물관이나 한라수목원을 방문
# - 숙박: 제주시내 호텔에서 하루를 마무리
#
# **3일차**
# - 아침: 호텔에서 체크아웃 후 한라산 국립공원으로 이동하여 자연 트레킹을 즐기기
# - 점심: 한라산 국립공원 내의 식당에서 맛있는 돌솥밥 먹기
# - 오후: 제주 마식령 해변으로 이동하여 바다 풀무드나 볼거리 즐기기
# - 저녁: 공항 근처에서 저녁 식사 후 제주 국제공항으로 이동
#
# 이렇게 제주도 2박 3일 여행 일정을 계획해 보았습니다. 즐거운 여행 되시길 바랍니다!

# %% [markdown]
# ## **3.LangChain으로 모델 사용하기**

# %% [markdown]
# ### (1) 랭체인으로 LLM 모델 연결

# %%
# langeuage_models
chat = ChatOpenAI(model="gpt-3.5-turbo")

result = chat([HumanMessage(content="안녕하세요!")])
print(result.content)
# Out:
# 안녕하세요! 무엇을 도와드릴까요?

# %% [markdown]
# ### (2) 역할 부여하기

# %%
# langeuage_models
chat = ChatOpenAI(model="gpt-3.5-turbo")

sys_role = '당신은 애국심을 가지고 있는 건전한 대한민국 국민입니다.'
question = "독도는 어느나라 땅이야?"

result = chat([HumanMessage(content = question), SystemMessage(content = sys_role)])
print(result.content)
# Out:
# 독도는 대한민국의 영토입니다. 일본이 주장하는 일본명칭인 '다케시마'가 아닌, 한국명칭인 '독도'로 알려져 있습니다. 대한민국 정부는 독도가 우리 영토임을 국제사회에 알리고 있으며, 독도를 지키기 위해 계속 노력하고 있습니다.

# %% [markdown]
# ### (3) [참조]Streaming
# * 답변을 생성하는 대로 화면에 순차적으로 출력

# %%
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

chat = ChatOpenAI(model="gpt-3.5-turbo",
                  streaming=True, callbacks=[StreamingStdOutCallbackHandler()])  # 스트리밍 설정

sys_role = '당신은 세계 최고의 요리사이자, 요리 선생님입니다. 당신은 항상 친절하고 정확하게 요리법을 가르칩니다.'
question = "한국식 후라이드치킨 만드는 방법 알려줘?"
result = chat([HumanMessage(content=question), SystemMessage(content = sys_role)])
# Out:
# 한국식 후라이드치킨을 만드는 방법은 다음과 같습니다:
#
# 재료:
# - 닭 튀김을 위한 닭 조각(허벅지, 날개, 등)
# - 밀가루
# - 계란
# - 빵가루
# - 식용유
# - 소스를 위한 간장, 설탕, 다진 마늘, 다진 생강, 고추장
#
# 1. 닭 조각을 소금과 후추로 조금씩 조리고, 냉장고에서 1시간 정도 숙성시킨다.
#
# 2. 밀가루, 계란, 빵가루를 준비한다. 밀가루에 소금과 후추를 넣고 섞은 후, 닭 조각을 밀가루에 묻힌다.
#
# 3. 계란을 풀고 닭 조각을 계란에 담그고, 다시 빵가루에 묻힌다.
#
# 4. 깊은 팬에 식용유를 넉넉하게 넣고 중불에서 닭 조각을 튀긴다. 두 번 튀긴 후에는 골고루 색이 나도록 조리한다.
#
# 5. 소스를 만든다. 간장, 설탕, 다진 마늘, 다진 생강, 고추장을 섞어 소스를 만든 후, 튀긴 닭 조각에 소스를 발라준다.
#
# 6. 닭 조각을 접시에 담고, 파슬리 또는 참깨를 뿌려 마무리한다.
#
# 7. 핫소스나 마요네즈와 함께 내놓으면 더욱 맛있게 즐길 수 있다.
#
# 즐거운 식사 되세요!
