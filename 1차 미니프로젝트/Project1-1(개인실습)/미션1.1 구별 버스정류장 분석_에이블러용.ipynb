# %% [markdown]
# # 안녕하세요, 에이블러 여러분!
# ## AIVLE스쿨 1차 미니프로젝트 '서울시 생활정보 기반 대중교통 수요 분석 ' 과정에 오신 여러분을 환영합니다.
# * 본 과정에서는 실제 사례와 데이터를 기반으로 문제를 해결하는 전체 과정을 자기 주도형 실습으로 진행해볼 예정입니다.
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.
# ## "버스 정류장 데이터" 를 확인해 보도록 하겠습니다

# %%
# 필요 라이브러리부터 설치합니다.
# %pip install pandas seaborn

# %% [markdown]
# ## 기본전제
# * 제공되는 기본/추가 데이터는 '에이블러용' 폴더에 있습니다.
#
# [기본 데이터]
# * 1.1 bus_station_boarding_month_202401.csv
#
# * 서울시 버스노선별 정류장별 승하차 인원 정보
# * https://data.seoul.go.kr/dataList/OA-12912/S/1/datasetView.do
#
#
# [추가 데이터]
# * 1.1 bus_station_202401.xlsx
#
# * 서울시 버스정류장 위치정보
# * https://data.seoul.go.kr/dataList/OA-15067/S/1/datasetView.do

# %% [markdown]
# ---

# %% [markdown]
# # 1.데이터 불러오기
# ## 모든 미니 프로젝트의 시작은 '데이터 불러오기' 부터입니다.

# %% [markdown]
# ###  데이터 프레임을 불러오고 변수로 저장(CSV 기준으로 진행)
# * csv : pd.read_csv("파일이름. csv")
# * txt : pd.read_csv("파일이름. csv", sep="구분자")
# * xlsx : pd.read_excel('파일이름.xlsx')
# * pickle : pd.read_pickle("파일이름.pkl") <br>
#  [참고] pickle은 sklearn 라이브러리를 통해 모델을 학습시키고 저장할 때 많이 사용, 파이썬의 모든 객체를 파일로 저장할 수 있다.

# %% [markdown]
# #### [실습문제1] 데이터 로딩
# * Pandas 라이브러리를 활용해서 '1.1 bus_station_boarding_month_202401.csv'파일을 'bus_station' 변수에 저장하세요.
#     * 데이터 파일 로딩시 참고 사항
#         * 구분자(sep)는 ',' 입니다
#         * cp949 인코더를 사용해 주세요

# %%
# 아래 실습코드를 실행해주세요.

import sys
import numpy as np
import pandas as pd

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

bus_station = pd.read_csv('1.1 bus_station_boarding_month_202401.csv', sep=",", encoding="cp949")

# %%
# 데이터 프레임의 Shape을 확인합니다.

bus_station.shape
# Out:
# (1048575, 8)

# %% [markdown]
# ---

# %% [markdown]
# # 2.기본 정보 확인 및 클렌징
#
# + 데이터 클렌징 : 결측치, 이상치 등을 제거하여 데이터 분석 결과가 왜곡 되는 문제를 방지하기 위한 정제 과정

# %% [markdown]
# #### [실습문제2] 기본 정보 확인하기
# * 'bus_station' 데이터의 정보를 확인해보세요.
# * 'describe', 'info', 'head' 등 전부 활용해 보세요.

# %%
# head()
bus_station.head()

# %%
# tail()
bus_station.tail()

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# info()
bus_station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258860 entries, 0 to 1258859
# Data columns (total 9 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   사용일자        1258860 non-null  int64
#  1   노선번호        1258860 non-null  object
#  2   노선명         1258860 non-null  object
#  3   표준버스정류장ID   1258860 non-null  object
#  4   버스정류장ARS번호  1258860 non-null  object
#  5   역명          1258860 non-null  object
#  6   승차총승객수      1258860 non-null  int64
#  7   하차총승객수      1258860 non-null  int64
#  8   등록일자        1258860 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 86.4+ MB

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# describe()

bus_station.describe()
# Out:
#                사용일자     버스정류장ARS번호         승차총승객수         하차총승객수          등록일자
# count  7.291230e+05  729123.000000  729123.000000  729123.000000  7.291230e+05
# mean   2.024011e+07   16493.356553     106.796263     104.507551  2.024012e+07
# std    7.455281e+00    6350.417487     153.043231     139.761821  7.455281e+00
# min    2.024010e+07    1001.000000       0.000000       0.000000  2.024010e+07
# 25%    2.024011e+07   13008.000000      14.000000      17.000000  2.024011e+07
# 50%    2.024011e+07   17115.000000      59.000000      64.000000  2.024012e+07
# 75%    2.024012e+07   22005.000000     141.000000     140.000000  2.024012e+07
# max    2.024013e+07   25990.000000    4031.000000    3483.000000  2.024013e+07

# %% [markdown]
# #### [실습문제3] 위 데이터에서 버스정류장 위치를 구 별로 구분 해보기
#
# * 'bus_station' 데이터의 정보를 확인해보세요.
#
# * 버스정류장 ARS번호의 앞 두자리가 구를 의미합니다.
#
# * '자치구' column을 추가 -> 정류장이 위치한 구 이름을 등록

# %%
# "버스정류장ARS번호" 컬럼 확인하기

bus_station[['버스정류장ARS번호']]
# Out:
#         버스정류장ARS번호
# 0            06178
# 1            22337
# 2            22336
# 3            22334
# 4            22333
# ...            ...
# 1258855      08535
# 1258856      35218
# 1258857      22027
# 1258858      39042
# 1258859      35222
#
# [1258860 rows x 1 columns]

# %%
# 버스정류장 ARS번호에서 시작하는 앞자리 2개로 '자치구'라는 새로운 컬럼 생성
# str() : 정수나 실수를 문자열 형태로 바꿔주는 함수, slice()

# '버스정류장ARS번호'에서 앞자리 2자리를 추출하여 '자치구' 컬럼 생성
bus_station.loc[:, '자치구'] = bus_station['버스정류장ARS번호'].astype(str).str.slice(start= 0, stop=-3)
bus_station[['자치구']]
# Out:
#         자치구
# 0         6
# 1        22
# 2        22
# 3        22
# 4        22
# ...      ..
# 1048570   1
# 1048571   1
# 1048572   1
# 1048573   8
# 1048574   1
#
# [1048575 rows x 1 columns]

# %% [markdown]
# * 버스정류장 ARS 번호 : 01~25까지 앞 숫자 두개가 위치한 구를 의미
#     01. 종로구
#     02. 중구
#     03. 용산구
#     04. 성동구
#     05. 광진구
#     06. 동대문구
#     07. 중랑구
#     08. 성북구
#     09. 강북구
#     10. 도봉구
#     11. 노원구
#     12. 은평구
#     13. 서대문구
#     14. 마포구
#     15. 양천구
#     16. 강서구
#     17. 구로구
#     18. 금천구
#     19. 영등포구
#     20. 동작구
#     21. 관악구
#     22. 서초구
#     23. 강남구
#     24. 송파구
#     25. 강동구

# %%
# 구 코드를 구 이름으로 변환하기
# map() : 리스트, 튜플 등 반복 가능한 데이터 집합을 입력으로 받아 변환하는 함수

bus_station['자치구'] = bus_station['자치구'].map({
    '1': '종로구',
    '2': '중구',
    '3': '용산구',
    '4': '성동구',
    '5': '광진구',
    '6': '동대문구',
    '7': '중랑구',
    '8': '성북구',
    '9': '강북구',
    '10': '도봉구',
    '11': '노원구',
    '12': '은평구',
    '13': '서대문구',
    '14': '마포구',
    '15': '양천구',
    '16': '강서구',
    '17': '구로구',
    '18': '금천구',
    '19': '영등포구',
    '20': '동작구',
    '21': '관악구',
    '22': '서초구',
    '23': '강남구',
    '24': '송파구',
    '25': '강동구'})

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# tail(10)

bus_station.tail(10)
# Out:
#              사용일자  노선번호               노선명 버스정류장ARS번호                 역명  \
# 1048565  20240126  종로05  종로05(서대문역~배화여중고)       1849      강북삼성병원(00027)
# 1048566  20240126  종로03   종로03(낙산공원~종로5가)       1825        창신초교(00021)
# 1048567  20240126  종로05  종로05(서대문역~배화여중고)       1796  배화여중고.매동초교(00017)
# 1048568  20240126  종로05  종로05(서대문역~배화여중고)       1820     교남동주민센터(00022)
# 1048569  20240126  종로05  종로05(서대문역~배화여중고)       1554    독립문역3번출구(00006)
# 1048570  20240126  종로05  종로05(서대문역~배화여중고)       1837      스위스대사관(00025)
# 1048571  20240126  종로05  종로05(서대문역~배화여중고)       1831        월암공원(00024)
# 1048572  20240126  종로05  종로05(서대문역~배화여중고)       1514    적십자병원후문앞(00002)
# 1048573  20240126  성북07  성북07(정릉4동종점~길음역)       8454      정릉4동종점(00014)
# 1048574  20240126  종로05  종로05(서대문역~배화여중고)       1587   신학대학교총회본부(00011)
#
#          승차총승객수  하차총승객수      등록일자  자치구
# 1048565       6     175  20240129  금천구
# 1048566      63      86  20240129  금천구
# 1048567      22      91  20240129  구로구
# 1048568       7      25  20240129  금천구
# 1048569     343     191  20240129  양천구
# 1048570       1      19  20240129  금천구
# 1048571      25      21  20240129  금천구
# 1048572       9       6  20240129  양천구
# 1048573       0     181  20240129  NaN
# 1048574      13      68  20240129  양천구

# %% [markdown]
# #### [실습문제4] 결측치 처리하기

# %%
# (가상), (기점가상) 정류장은 ARS번호가 '~'로 나옵니다.
# (가상) 정류장 : 버스정보시스템 상에서 위치 정보를 표시하기 위해 임의로 가상의 정류장을 설정, 실제하지 않음
# '버스정류장ARS번호'가 '~'인 곳을 확인해주세요.

bus_station.loc[bus_station['버스정류장ARS번호'] == '~']
# Out:
#              사용일자  노선번호                      노선명 버스정류장ARS번호  \
# 699      20240101   441      441번(월암공영차고지~신사사거리)          ~
# 1261     20240101  7021     7021번(은평공영차고지~롯데백화점)          ~
# 1337     20240101  7017     7017번(은평공영차고지~롯데백화점)          ~
# 1427     20240101  7016         7016번(은평차고지~상명대)          ~
# 3332     20240101  750B         750B번(은평차고지~서울대)          ~
# ...           ...   ...                      ...        ...
# 1040945  20240126   271  271번(용마문화복지센터~월드컵파크7단지)          ~
# 1040953  20240126   271  271번(용마문화복지센터~월드컵파크7단지)          ~
# 1041836  20240126   N64    N64번(염곡공영차고지~강서공영차고지)          ~
# 1042754  20240126   N72  N72중랑 (중랑공영차고지~은평공영차고지)          ~
# 1043252  20240126   01A        01A번(예장주차장~예장주차장)          ~
#
#                                역명  승차총승객수  하차총승객수      등록일자  자치구
# 699            월암차고지(종점가상)(00126)       0       1  20240104  NaN
# 1261           은평공영차고지(가상)(00076)       0      10  20240104  NaN
# 1337           은평공영차고지(가상)(00090)       0      10  20240104  NaN
# 1427           은평공영차고지(가상)(00107)       0      16  20240104  NaN
# 3332           은평공영차고지(가상)(00076)       0      15  20240104  NaN
# ...                           ...     ...     ...       ...  ...
# 1040945         경성여객(종점가상)(00125)       0      35  20240129  NaN
# 1040953         경성여객(기점가상)(00001)      61      12  20240129  NaN
# 1041836         대흥교통(기점가상)(00001)       0       1  20240129  NaN
# 1042754      중랑공영차고지(기점가상)(00001)       3       0  20240129  NaN
# 1043252  남산예장버스환승주차장(종점가상)(00025)       2     165  20240129  NaN
#
# [4358 rows x 9 columns]

# %%
# NaN 값을 제거 해주세요.
# dropna()

# '~' 값을 NaN 값으로 대체
bus_station['버스정류장ARS번호'] = np.where(bus_station['버스정류장ARS번호'] == '~', np.nan, bus_station['버스정류장ARS번호'])

# NaN 값을 포함하는 행 제거 후 데이터프레임에 다시 할당
bus_station = bus_station.dropna()

# %%
# 컬럼별 NaN 값이 있는지 확인, info()

bus_station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 729123 entries, 1 to 1048574
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   사용일자        729123 non-null  int64
#  1   노선번호        729123 non-null  object
#  2   노선명         729123 non-null  object
#  3   버스정류장ARS번호  729123 non-null  object
#  4   역명          729123 non-null  object
#  5   승차총승객수      729123 non-null  int64
#  6   하차총승객수      729123 non-null  int64
#  7   등록일자        729123 non-null  int64
#  8   자치구         729123 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 55.6+ MB

# %%
# "버스정류장ARS번호" dtype을 정수형(int)으로 변경

bus_station['버스정류장ARS번호'] = bus_station['버스정류장ARS번호'].astype(int)

bus_station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 960811 entries, 0 to 1048574
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   사용일자        960811 non-null  int64
#  1   노선번호        960811 non-null  object
#  2   노선명         960811 non-null  object
#  3   버스정류장ARS번호  960811 non-null  int32
#  4   역명          960811 non-null  object
#  5   승차총승객수      960811 non-null  int64
#  6   하차총승객수      960811 non-null  int64
#  7   등록일자        960811 non-null  int64
#  8   자치구         960811 non-null  object
# dtypes: int32(1), int64(4), object(4)
# memory usage: 69.6+ MB

# %% [markdown]
# #### [실습문제5] 구별로 버스정류장의 개수 확인하기 (서울시)

# %%
# 자치구별 버스정류장 고유값들의 갯수를 출력하여 'bus_station_count' 변수로 저장
# nunique(), groupby()

bus_station_count = bus_station.groupby('자치구')['버스정류장ARS번호'].nunique()

bus_station_count

#bus_station_count.to_csv('bus_count.csv', index=True)
# Out:
# 자치구
# 강남구     501
# 강동구     367
# 강북구     410
# 강서구     567
# 관악구     468
# 광진구     280
# 구로구     486
# 금천구     347
# 노원구     496
# 도봉구     368
# 동대문구    308
# 동작구     441
# 마포구     565
# 서대문구    460
# 서초구     601
# 성동구     433
# 성북구     599
# 송파구     470
# 양천구     323
# 영등포구    467
# 용산구     326
# 은평구     497
# 종로구     357
# 중구      174
# 중랑구     428
# Name: 버스정류장ARS번호, dtype: int64

# %%
# 중랑구에 428개의 버스정류장이 있다는데, 실제 ARS번호를 확인해봅시다.
# 자치구별 버스정류장 고유값들을 출력하여 'bus_staiton_unique' 변수로 저장
# 중랑구 버스정류장ARS번호 전체 출력

# 자치구별 버스정류장 고유값들을 출력하여 'bus_station_unique' 변수에 저장
bus_station_unique = bus_station.groupby('자치구')['버스정류장ARS번호'].unique()

# 중랑구 버스정류장ARS번호 전체 출력
print(bus_station[bus_station['자치구'] == '중랑구']['버스정류장ARS번호'].unique())
# Out:
# [7142 7136 7138 7465 7440 7438 7432 7433 7435 7434 7008 7007 7336 7335
#  7334 7333 7297 7296 7295 7294 7274 7273 7272 7271 7270 7269 7249 7247
#  7245 7243 7233 7231 7229 7227 7225 7223 7222 7221 7220 7219 7218 7217
#  7216 7199 7197 7195 7194 7145 7144 7131 7129 7117 7006 7005 7004 7003
#  7002 7001 7616 7817 7830 7828 7831 7021 7587 7595 7592 7593 7594 7820
#  7818 7819 7516 7515 7502 7501 7554 7553 7500 7499 7498 7496 7494 7821
#  7829 7832 7043 7045 7060 7057 7054 7058 7020 7014 7011 7013 7015 7016
#  7446 7551 7466 7463 7464 7462 7451 7450 7454 7455 7452 7453 7456 7448
#  7332 7331 7330 7329 7328 7327 7325 7300 7299 7298 7250 7248 7246 7244
#  7242 7232 7230 7228 7226 7224 7211 7210 7209 7208 7207 7206 7205 7204
#  7203 7192 7191 7190 7189 7188 7187 7143 7141 7140 7118 7410 7476 7302
#  7304 7305 7306 7337 7418 7010 7009 7550 7303 7307 7420 7421 7424 7012
#  7178 7180 7181 7182 7183 7184 7185 7186 7111 7112 7113 7114 7115 7116
#  7275 7276 7277 7278 7279 7280 7261 7262 7263 7264 7265 7266 7267 7268
#  7443 7408 7444 7409 7411 7119 7120 7121 7122 7123 7146 7147 7148 7149
#  7150 7151 7152 7153 7154 7155 7156 7157 7158 7159 7160 7161 7162 7163
#  7164 7165 7193 7196 7439 7442 7447 7457 7460 7459 7458 7166 7167 7171
#  7172 7174 7175 7176 7179 7168 7170 7173 7177 7169 7240 7241 7415 7101
#  7102 7103 7104 7128 7105 7106 7107 7108 7109 7110 7425 7426 7134 7198
#  7200 7308 7309 7251 7252 7395 7397 7530 7523 7521 7508 7504 7436 7527
#  7525 7519 7517 7512 7253 7510 7505 7254 7524 7255 7529 7256 7507 7526
#  7257 7528 7511 7258 7509 7518 7259 7260 7281 7282 7288 7289 7290 7291
#  7292 7293 7347 7354 7430 7431 7135 7212 7213 7286 7355 7356 7357 7358
#  7359 7360 7361 7362 7363 7364 7365 7366 7367 7369 7370 7371 7372 7373
#  7375 7376 7377 7378 7380 7417 7429 7467 7124 7316 7319 7321 7348 7349
#  7350 7351 7352 7353 7379 7381 7382 7383 7384 7385 7386 7387 7388 7389
#  7390 7391 7392 7393 7394 7396 7398 7399 7422 7234 7235 7236 7237 7238
#  7239 7324 7346 7284 7461 7132 7133 7137 7401 7402 7403 7404 7405 7406
#  7407 7214 7215 7202 7201 7310 7311 7312 7313 7314 7315 7125 7283 7285
#  7287 7437 7130 7301 7317 7318 7320 7427 7017 7055 7491 7495 7552 7588
#  7827 7674 7675 7822 7506 7520 7503 7018]

# %%
# 서울 지역 외 '버스정류장ARS번호' 샘플 확인
# 중랑구의 버스정류장ARS번호 7674 인 정류장 확인해보기

# 서울 지역 외 '버스정류장ARS번호' 샘플 확인
bus_station[bus_station['버스정류장ARS번호'].astype(str).str.slice(stop=2).astype(int) > 25]

# 중랑구의 버스정류장ARS번호 7674 인 정류장 확인해보기
bus_station[(bus_station['자치구'] == '중랑구') & (bus_station['버스정류장ARS번호'] == 7674)]
# Out:
#              사용일자  노선번호                노선명  표준버스정류장ID  버스정류장ARS번호  \
# 43608    20240102  9409  9409번(구미동차고지~신사역)  206000779        7674
# 84449    20240103  9409  9409번(구미동차고지~신사역)  206000779        7674
# 206641   20240106  9409  9409번(구미동차고지~신사역)  206000779        7674
# 287124   20240108  9409  9409번(구미동차고지~신사역)  206000779        7674
# 327856   20240109  9409  9409번(구미동차고지~신사역)  206000779        7674
# 450342   20240112  9409  9409번(구미동차고지~신사역)  206000779        7674
# 612051   20240116  9409  9409번(구미동차고지~신사역)  206000779        7674
# 652849   20240117  9409  9409번(구미동차고지~신사역)  206000779        7674
# 693641   20240118  9409  9409번(구미동차고지~신사역)  206000779        7674
# 814818   20240121  9409  9409번(구미동차고지~신사역)  206000779        7674
# 855341   20240122  9409  9409번(구미동차고지~신사역)  206000779        7674
# 896148   20240123  9409  9409번(구미동차고지~신사역)  206000779        7674
# 977959   20240125  9409  9409번(구미동차고지~신사역)  206000779        7674
# 1018890  20240126  9409  9409번(구미동차고지~신사역)  206000779        7674
# 1099424  20240128  9409  9409번(구미동차고지~신사역)  206000779        7674
# 1139706  20240129  9409  9409번(구미동차고지~신사역)  206000779        7674
#
#                   역명  승차총승객수  하차총승객수      등록일자  자치구
# 43608    이우중고(00005)       1       1  20240105  중랑구
# 84449    이우중고(00005)       0       1  20240106  중랑구
# 206641   이우중고(00005)       3       0  20240109  중랑구
# 287124   이우중고(00005)       0       2  20240111  중랑구
# 327856   이우중고(00005)       1       4  20240112  중랑구
# 450342   이우중고(00005)       1       0  20240115  중랑구
# 612051   이우중고(00005)       0       1  20240119  중랑구
# 652849   이우중고(00005)       1       0  20240120  중랑구
# 693641   이우중고(00005)       0       1  20240121  중랑구
# 814818   이우중고(00005)       2       0  20240124  중랑구
# 855341   이우중고(00005)       0       1  20240125  중랑구
# 896148   이우중고(00005)       0       2  20240126  중랑구
# 977959   이우중고(00005)       0       1  20240128  중랑구
# 1018890  이우중고(00005)       0       2  20240129  중랑구
# 1099424  이우중고(00005)       1       2  20240131  중랑구
# 1139706  이우중고(00005)       1       0  20240201  중랑구

# %%
# 서울의 버스 정류장 데이터만 포함하고 있는 excel 파일 열기 ('1.1 bus_station_202401.xlsx')
# https://data.seoul.go.kr/dataList/OA-15067/S/1/datasetView.do (출처:서울열린데이터광장)
# 'only_seoul' 변수로 저장

only_seoul = pd.read_excel('1.1 bus_station_202401.xlsx')

# %%
# 데이터 구조 확인, info()

only_seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11263 entries, 0 to 11262
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   NODE_ID  11263 non-null  int64
#  1   ARS_ID   11263 non-null  int64
#  2   정류소명     11263 non-null  object
#  3   X좌표      11263 non-null  float64
#  4   Y좌표      11263 non-null  float64
#  5   정류소타입    11263 non-null  object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 528.1+ KB

# %%
# 데이터 확인

only_seoul
# Out:
#        ARS_ID           정류소명
# 0        1001        종로2가사거리
# 1        1002    창경궁.서울대학교병원
# 2        1003      명륜3가.성대입구
# 3        1004       종로2가.삼일교
# 4        1005  혜화동로터리.여운형활동터
# ...       ...            ...
# 11258   25995          우성아파트
# 11259   25996          우성아파트
# 11260   25997           조일약국
# 11261   25998           성내시장
# 11262   25999    천호우체국.로데오거리
#
# [11263 rows x 2 columns]

# %%
# 서울 지역 외 '버스정류장ARS번호' 샘플 확인

#서울 지역 밖에 없는데 어떻게 서울 지역 외 버스정류장ARS번호 샘플을 확인할 수 있을까?

# %%
# 'ARS-ID'열 이름을 '버스정류장ARS번호'로 바꾸기

only_seoul.rename(columns={'ARS_ID': '버스정류장ARS번호'}, inplace=True)
only_seoul.head()
# Out:
#    버스정류장ARS번호           정류소명
# 0        1001        종로2가사거리
# 1        1002    창경궁.서울대학교병원
# 2        1003      명륜3가.성대입구
# 3        1004       종로2가.삼일교
# 4        1005  혜화동로터리.여운형활동터

# %%
# 'only_seoul'과 'bus_station' 데이터 병합

merged_data = pd.merge(only_seoul, bus_station, on='버스정류장ARS번호', how='inner')

merged_data
# Out:
#         버스정류장ARS번호        정류소명      사용일자  노선번호                    노선명  \
# 0             1001     종로2가사거리  20240101   N37  N37번(송파공영차고지~진관공영차고지)
# 1             1001     종로2가사거리  20240101   N37  N37번(진관공영차고지~송파공영차고지)
# 2             1001     종로2가사거리  20240101   470       470번(상암차고지~안골마을)
# 3             1001     종로2가사거리  20240101   741      741번(진관차고지~헌인릉입구)
# 4             1001     종로2가사거리  20240102   N37  N37번(송파공영차고지~진관공영차고지)
# ...            ...         ...       ...   ...                    ...
# 957604       25990  암사삼성.현대아파트  20240122  강동02     강동02(가래여울~암사동서원마을)
# 957605       25990  암사삼성.현대아파트  20240123  강동02     강동02(가래여울~암사동서원마을)
# 957606       25990  암사삼성.현대아파트  20240124  강동02     강동02(가래여울~암사동서원마을)
# 957607       25990  암사삼성.현대아파트  20240125  강동02     강동02(가래여울~암사동서원마을)
# 957608       25990  암사삼성.현대아파트  20240126  강동02     강동02(가래여울~암사동서원마을)
#
#                        역명  승차총승객수  하차총승객수      등록일자  자치구
# 0          종로2가사거리(00032)       3       5  20240104  종로구
# 1          종로2가사거리(00089)      21      11  20240104  종로구
# 2          종로2가사거리(00066)      98     117  20240104  종로구
# 3          종로2가사거리(00075)      92     116  20240104  종로구
# 4          종로2가사거리(00032)       2      11  20240105  종로구
# ...                   ...     ...     ...       ...  ...
# 957604  암사삼성.현대아파트(00044)      80      27  20240125  강동구
# 957605  암사삼성.현대아파트(00044)      90      29  20240126  강동구
# 957606  암사삼성.현대아파트(00044)      90      23  20240127  강동구
# 957607  암사삼성.현대아파트(00044)      88      30  20240128  강동구
# 957608  암사삼성.현대아파트(00044)      64      31  20240129  강동구
#
# [957609 rows x 10 columns]

# %%
# 구 별로 버스 정류장의 개수 확인하기, 'seoul_bus_station_ARS' 변수로 저장

# '자치구' 열을 기준으로 그룹화하고 각 그룹별 버스 정류장 개수 세기
seoul_bus_station_ARS = merged_data.groupby('자치구').size()

# 결과 확인
print(seoul_bus_station_ARS)
# Out:
# 자치구
# 강남구     56470
# 강동구     27469
# 강북구     31614
# 강서구     45796
# 관악구     43443
# 광진구     22005
# 구로구     36654
# 금천구     25457
# 노원구     42630
# 도봉구     27261
# 동대문구    35512
# 동작구     38034
# 마포구     47267
# 서대문구    48407
# 서초구     52099
# 성동구     26202
# 성북구     44988
# 송파구     47944
# 양천구     36061
# 영등포구    42731
# 용산구     29140
# 은평구     45846
# 종로구     36504
# 중구      27600
# 중랑구     40475
# dtype: int64

# %%
# 서울시에 있는 버스정류장 개수 구하기

# 모든 그룹별 개수를 더하여 총 버스 정류장 개수 구하기
seoul_bus_station_ARS.sum()
# Out:
# 957609

# %% [markdown]
# #### [실습문제6] 구 별로 버스 노선의 개수 확인하기

# %%
# 자치구별 노선번호의 개수 구하기, 'seoul_bus_staion_line' 변수로 저장

seoul_bus_station_line = merged_data.groupby(['자치구', '노선번호']).size()

print(seoul_bus_station_line)
# Out:
# 자치구  노선번호
# 강남구  140       26
#      141      910
#      142       26
#      143     1092
#      144       26
#              ...
# 중랑구  N61     1400
#      N62      574
#      N72     1644
#      중랑01     310
#      중랑02     650
# Length: 1862, dtype: int64

# %% [markdown]
# #### [실습문제7] 각 구별로 승차 총 승객수, 하차 총 승객수 구하기

# %%
# 자치구별 "승차총승객수","하차총승객수"의 합 구하기, 'seoul_bus_station_sum' 변수로 저장
# groupby()

# '자치구' 열을 기준으로 그룹화하고 "승차총승객수"와 "하차총승객수"의 합 구하기
seoul_bus_station_sum = merged_data.groupby('자치구')[['승차총승객수', '하차총승객수']].sum()

# 결과 출력
print(seoul_bus_station_sum)
# Out:
#        승차총승객수   하차총승객수
# 자치구
# 강남구   8296564  7862045
# 강동구   2999118  2933820
# 강북구   4805944  4638276
# 강서구   4778777  4758161
# 관악구   7005050  7164808
# 광진구   2848551  2868440
# 구로구   5023677  4809615
# 금천구   3764711  3621261
# 노원구   4255714  4189837
# 도봉구   3315634  3226684
# 동대문구  5442269  5317464
# 동작구   4904962  4732598
# 마포구   5377311  5231695
# 서대문구  6050531  5944747
# 서초구   7063133  6868550
# 성동구   2838587  2793112
# 성북구   6045725  6059449
# 송파구   5681324  5680217
# 양천구   4159746  3999280
# 영등포구  5945854  6008374
# 용산구   4170066  4082486
# 은평구   5124251  5037883
# 종로구   5389830  5206394
# 중구    3750724  3644971
# 중랑구   3851183  3797220

# %% [markdown]
# #### [실습문제8] 각 구별 승차 평균 승객수, 하차 평균 승객수 구하기

# %%
# 자치구별 "승차총승객수","하차총승객수"의 평균 구하기, 'seoul_bus_station_mean' 변수로 저장
# '승차총승객수' -> '승차평균승객수', '하차총승객수' -> '하차평균승객수'로 열이름 변경

merged_data.rename(columns={'승차총승객수': '승차평균승객수', '하차총승객수':'하차평균승객수'}, inplace=True)
seoul_bus_station_mean = merged_data.groupby('자치구')[['승차평균승객수', '하차평균승객수']].mean()
print(seoul_bus_station_mean)
# Out:
#          승차평균승객수     하차평균승객수
# 자치구
# 강남구   123.257234  116.824633
# 강동구    91.578944   89.588445
# 강북구   126.465395  122.036345
# 강서구    86.932767   86.542122
# 관악구   134.946712  138.040996
# 광진구   107.491706  108.267985
# 구로구   114.700415  109.759781
# 금천구   123.088384  118.410025
# 노원구    83.356439   82.041989
# 도봉구   101.649829   98.878985
# 동대문구  127.573018  124.657074
# 동작구   108.467845  104.620655
# 마포구    95.578543   92.983159
# 서대문구  104.720330  102.849216
# 서초구   113.621221  110.463886
# 성동구    90.495039   88.994581
# 성북구   112.288788  112.480017
# 송파구    99.003483   98.964751
# 양천구    96.452095   92.738804
# 영등포구  116.711217  117.971168
# 용산구   119.962938  117.447907
# 은평구    93.725603   92.127252
# 종로구   123.298104  119.119987
# 중구    113.699710  110.530616
# 중랑구    79.082866   77.969784

# %% [markdown]
# #### [실습문제9] 데이터 프레임 합치기

# %%
# 네 개 파일을 합쳐주세요.

# seoul_bus_station_ARS
# seoul_bus_station_line
# seoul_bus_station_sum
# seoul_bus_station_mean


# 네 개의 데이터프레임을 리스트로 만듦
data_frames = [seoul_bus_station_ARS, seoul_bus_station_line, seoul_bus_station_sum, seoul_bus_station_mean]

# 수직으로 합침
data_frames
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 10
#       1 # 네 개 파일을 합쳐주세요.
#       2
#       3 # seoul_bus_station_ARS
#    (...)
#       8
#       9 # 네 개의 데이터프레임을 리스트로 만듦
# ---> 10 data_frames = [seoul_bus_station_ARS, seoul_bus_station_line, seoul_bus_station_sum, seoul_bus_station_mean]
#      12 # 수직으로 합침
#      13 data_frames
#
# NameError: name 'seoul_bus_station_sum' is not defined

# %%
# '버스정류장ARS번호' -> '정류장수', '노선번호' -> '노선수'로 열이름 변경

merged_data = merged_data.rename(columns={'버스정류장ARS번호':'정류장수', '노선번호':'노선수'})

merged_data
# Out:
#            NODE_ID   정류장수        정류소명         X좌표        Y좌표 정류소타입      사용일자  \
# 0        100000001   1001     종로2가사거리  126.987752  37.569806  중앙차로  20240101
# 1        100000001   1001     종로2가사거리  126.987752  37.569806  중앙차로  20240101
# 2        100000001   1001     종로2가사거리  126.987752  37.569806  중앙차로  20240101
# 3        100000001   1001     종로2가사거리  126.987752  37.569806  중앙차로  20240101
# 4        100000001   1001     종로2가사거리  126.987752  37.569806  중앙차로  20240102
# ...            ...    ...         ...         ...        ...   ...       ...
# 1150115  124900108  25990  암사삼성.현대아파트  127.128549  37.553318  마을버스  20240127
# 1150116  124900108  25990  암사삼성.현대아파트  127.128549  37.553318  마을버스  20240128
# 1150117  124900108  25990  암사삼성.현대아파트  127.128549  37.553318  마을버스  20240129
# 1150118  124900108  25990  암사삼성.현대아파트  127.128549  37.553318  마을버스  20240130
# 1150119  124900108  25990  암사삼성.현대아파트  127.128549  37.553318  마을버스  20240131
#
#           노선수                    노선명  표준버스정류장ID                 역명  승차총승객수  \
# 0         N37  N37번(송파공영차고지~진관공영차고지)  100000001     종로2가사거리(00032)       3
# 1         N37  N37번(진관공영차고지~송파공영차고지)  100000001     종로2가사거리(00089)      21
# 2         470       470번(상암차고지~안골마을)  100000001     종로2가사거리(00066)      98
# 3         741      741번(진관차고지~헌인릉입구)  100000001     종로2가사거리(00075)      92
# 4         N37  N37번(송파공영차고지~진관공영차고지)  100000001     종로2가사거리(00032)       2
# ...       ...                    ...        ...                ...     ...
# 1150115  강동02     강동02(가래여울~암사동서원마을)  124900108  암사삼성.현대아파트(00044)      41
# 1150116  강동02     강동02(가래여울~암사동서원마을)  124900108  암사삼성.현대아파트(00044)      33
# 1150117  강동02     강동02(가래여울~암사동서원마을)  124900108  암사삼성.현대아파트(00044)      67
# 1150118  강동02     강동02(가래여울~암사동서원마을)  124900108  암사삼성.현대아파트(00044)      71
# 1150119  강동02     강동02(가래여울~암사동서원마을)  124900108  암사삼성.현대아파트(00044)      91
#
#          하차총승객수      등록일자  자치구
# 0             5  20240104  종로구
# 1            11  20240104  종로구
# 2           117  20240104  종로구
# 3           116  20240104  종로구
# 4            11  20240105  종로구
# ...         ...       ...  ...
# 1150115      10  20240130  강동구
# 1150116      19  20240131  강동구
# 1150117      24  20240201  강동구
# 1150118      30  20240202  강동구
# 1150119      28  20240203  강동구
#
# [1150120 rows x 15 columns]

# %%
# 데이터를 합친 결과를 확인합니다.

# %%
# 해당 데이터프레임을 csv 파일로 저장하세요.

# %% [markdown]
# ---

# %% [markdown]
# # 3.데이터 분석하기
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 데이터들의 패턴 탐색
#   * 변수들간의 관계 파악

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun')
sns.set(font="Malgun Gothic",
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %% [markdown]
# #### [실습문제10] 데이터 분포 알아보기
# * 다양한 변수를 기준으로 그래프를 그려보고 인사이트를 도출해보세요.

# %%
# 자치구별 정류장 수를 볼 수 있는 그래프를 출력해주세요.

# %%
# 위 차트를 통해 알게된 사실을 개인별로 정리해봅시다.
# 1.
# 2.
# 3.

# %% [markdown]
# ---
